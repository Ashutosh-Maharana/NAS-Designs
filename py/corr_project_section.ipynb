# %%
import pandas as pd

# %% [markdown]
# Figuring out which projects to choose

# %%
excel_file = "C:\\Users\\Ashutosh.Maharana\\OneDrive - Nortek, Inc\\Projects\\Correlations\\TB_Project_max_version.xlsx"
df_project_max_version = pd.read_excel(excel_file)
df_project_max_version.head(10)
# Out:
#   ProjSurKey  ProjectID  Version  Active  SavedDate          SavedBy  \
# 0        0-1          0        1    True 2025-04-14  Charles Gautier
# 1  100000-22     100000       22    True 2024-09-12   Fabrizio Ficca
# 2   100001-3     100001        3    True 2015-12-28    Ronald Flautz
# 3   100002-1     100002        1    True 2018-09-25    Darin Bennett
# 4  100003-16     100003       16    True 2017-03-02     Bill Willems
# 5   100004-4     100004        4    True 2016-01-25     Sean Garster
# 6   100005-1     100005        1    True 2020-10-02        Greg Lanz
# 7   100006-4     100006        4    True 2016-02-01    Ronald Flautz
# 8   100007-1     100007        1    True 2022-11-21  Mark Bettineski
# 9   100008-8     100008        8    True 2015-03-20     Sean Garster
#
#   HdaVersion                           JobName  \
# 0  11.3.0.12  BPA ADM Caserne Syst Ventilation
# 1     11.0.3               Test Project 100000
# 2      6.2.0                           VMC OMW
# ...

# %%
df_project_max_version.shape
# Out:
# (35017, 133)

# %%
columns_to_select = [
    "ProjSurKey", "ProjectID", "Version", "Active", "SavedDate", "TotalPrice",
    "BuildingType", "BuildingUse", "CleaningWrapping", "ClimateZone", "LeadTimeWeeks",
    "MarketSegment", "MeasurementSystem", "ProjectStage", "ProjectType", "QuoteNumber",
    "ReturnAirCoolingDB", "ReturnAirCoolingRH", "ReturnAirCoolingWB",
    "ReturnAirHeatingDB", "ReturnAirHeatingRH", "ReturnAirHeatingWB",
    "UserCity", "UserCountry", "UserState", "UserZipCode"
]

df_project_max_version = df_project_max_version[columns_to_select]

# %%
df_project_max_version.shape
# Out:
# (35017, 26)

# %%
df_project_max_version.to_excel("C:\\Users\\Ashutosh.Maharana\\OneDrive - Nortek, Inc\\Projects\\NAS-Designs\\Data\\df_project_max_version.xlsx")

# %%
excel_file = "C:\\Users\\Ashutosh.Maharana\\OneDrive - Nortek, Inc\\Projects\\Correlations\\TB_corr_UDC_category.xlsx"
df_udc_detail = pd.read_excel(excel_file)
df_udc_detail.head(10)
# Out:
#    ProjectID  Version  DashNo                                   DesignGuid  \
# 0     100003        7       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 1     100003       14       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 2     100003       12       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 3     100003        8       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 4     100003       15       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 5     100003       10       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 6     100003        9       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 7     100003        6       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 8     100003       13       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
# 9     100003       11       1  Design.52b62260-06f8-4c76-99e3-ead1648e1cc5
#
#    Active  SavedDate     AirTunnelName  \
# 0       1 2015-02-25  AirTunnel Supply
# 1       1 2016-04-15  AirTunnel Supply
# ...

# %%
df_udc_detail.shape
# Out:
# (49922, 14)

# %%
columns_to_select = [
     "ProjectID", "Version", "DashNo", "DesignGuid", "Active",
    "SavedDate", "AirTunnelKey", "SectionName","Description", "UDC_Key"
]

df_udc_detail = df_udc_detail[columns_to_select]

# %%
df_udc_detail.shape
# Out:
# (49922, 10)

# %%
excel_file = "C:\\Users\\Ashutosh.Maharana\\OneDrive - Nortek, Inc\\Projects\\Correlations\\TB_corr_airtunnel_component_details.xlsx"
df_design_detail_components = pd.read_excel(excel_file)
df_design_detail_components.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[39], line 2
#       1 excel_file = "C:\\Users\\Ashutosh.Maharana\\OneDrive - Nortek, Inc\\Projects\\Correlations\\TB_corr_airtunnel_component_details.xlsx"
# ----> 2 df_design_detail_components = pd.read_excel(excel_file)
#       3 df_design_detail_components.head(10)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...
